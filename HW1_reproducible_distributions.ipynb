# %% [markdown]
# # I want you to create a <i>reproducible research</i> code
# that means we want the reader to be able to reproduce every step of our analysis. when stochastic processes and random variables are involved that gets tricky, but since computers are unable to rpoduce truly random numbers, we can actually reproduce every series of "pseudo random" number generated by a computer as long as we know what seed is used. <i>The first seed will determin entirely the distribution that is generated, and the seeds of the following distriburions generated by the code!</i>

# %%
import os
import sys

# %% [markdown]
# #THIS IS THE MOST IMPORTANT PIECE OF THIS CODE!
# ##we must give numpy as seed for this code to be reproducible
# http://docs.scipy.org/doc/numpy/reference/generated/numpy.random.seed.html

# %%
#code here...
import numpy as np

np.random.seed(seed=1234)

# %% [markdown]
# ##use this function to generate 100 2-dimensional random datapoints in a gaussian distribution in 2 dimensions
#
# http://docs.scipy.org/doc/numpy/reference/generated/numpy.random.randn.html

# %%
np.random.seed(1)
#mean is 3, sd is 3
sample1 = 3*np.random.randn(100,2)+3
print sample1
# Out:
# [[  7.87303609e+00   1.16473076e+00]
#  [  1.41548474e+00  -2.18905866e-01]
#  [  5.59622289e+00  -3.90461609e+00]
#  [  8.23443529e+00   7.16379297e-01]
#  [  3.95711729e+00   2.25188887e+00]
#  [  7.38632381e+00  -3.18042213e+00]
#  [  2.03274839e+00   1.84783694e+00]
#  [  6.40130833e+00  -2.99673802e-01]
#  [  2.48271538e+00   3.66424746e-01]
#  [  3.12664124e+00   4.74844564e+00]
#  [ -3.01857532e-01   6.43417113e+00]
#  [  5.70477216e+00   4.50748302e+00]
#  [  5.70256785e+00   9.48816422e-01]
#  [  2.63132932e+00   1.92691697e-01]
#  [  2.19633576e+00   4.59106640e+00]
#  [  9.25017745e-01   1.80973942e+00]
#  [  9.38481900e-01   4.64383076e-01]
#  [  9.86261607e-01   2.96200620e+00]
#  [ -3.51931046e-01   3.70324709e+00]
#  [  7.97940653e+00   5.22613248e+00]
#  [  2.42449334e+00   3.37113108e-01]
#  [  7.58525119e-01   8.07736380e+00]
#  [  3.15242326e+00   1.08901306e+00]
#  [  3.57274645e+00   9.30076541e+00]
#  [  3.36047686e+00   4.85160933e+00]
#  [  3.90051096e+00   1.94325046e+00]
#  [ -4.27554594e-01   1.95197183e+00]
#  [  2.37331730e+00   4.75986957e+00]
#  [  5.51695024e+00   5.79330624e+00]
#  [  3.85676198e+00   5.65542349e+00]
#  [  7.36806177e-01   6.75860447e+00]
#  [  4.53878946e+00   2.10572149e+00]
#  [  4.46555444e+00   2.77328486e+00]
#  [  6.39488816e+00   7.55945045e+00]
#  [  9.55672622e+00  -1.18948901e+00]
#  [ -1.33234142e+00   1.48660241e+00]
#  [  3.48011121e+00   5.62850676e+00]
#  [  3.94690484e+00  -3.06660365e+00]
#  [  2.08138796e+00   5.48392393e+00]
#  [  3.69028421e+00   5.28603354e+00]
#  [  2.33301557e+00   2.39772579e+00]
#  [  3.55968417e+00   4.23015494e+00]
# %%
np.random.seed(2)
#mean is 5 ,sd is 3
sample2 = 3*np.random.randn(50,2) + 5
print sample2
# Out:
# [[  3.74972646   4.83119952]
#  [ -1.40858829   9.92081243]
#  [ -0.38030676   2.4747579 ]
#  [  6.50864425   1.26413574]
#  [  1.82614334   2.27297716]
#  [  6.65436213  11.87662404]
#  [  5.12461818   1.64622366]
#  [  6.61717496   3.2115209 ]
#  [  4.94260851   8.52500366]
#  [  2.75638715   5.02707575]
#  [  2.36567632   4.53069749]
#  [  5.76971136   2.03366285]
#  [  3.9835341    4.29144791]
#  [  3.08703496   1.43716314]
#  [  0.73634832   4.53951441]
#  [  4.19282912  11.69410037]
#  [ -2.30430273   5.33817951]
#  [  6.11133361   9.07890159]
#  [  6.50557162   2.46735889]
#  [  5.00002928   6.62705772]
#  [  4.05947541   7.31303521]
#  [ -0.60427196  10.193554  ]
#  [  9.40303403   3.99296798]
#  [  6.83402234   5.14391178]
#  [  2.51259413   5.26313066]
#  [  8.00109766   3.85672245]
#  [  3.87299173   4.77658771]
#  [  6.30048899   8.83513769]
#  [  3.09596208   6.52518873]
#  [  5.64834802  -0.57583716]
#  [  3.74205055   4.6030133 ]
#  [  4.88128928   5.9780103 ]
#  [ -1.12096915   5.13876657]
#  [  2.96697327   0.68168292]
#  [  6.57288929   7.20583873]
#  [  3.0402492    7.52736884]
#  [  3.85545055   5.19946703]
#  [  1.70378316   9.75346117]
#  [ -2.97834837   4.72564213]
#  [  7.08535882  -1.10039964]
#  [  4.43159221   4.768344  ]
#  [  7.47410902   8.74463876]
#  [  3.78832319   0.846444  ]
#  [  9.10170627   8.6536569 ]
#  [  3.61398396   6.05266548]
#  [  6.1455987    6.69882632]
#  [  5.61262394   9.22008872]
#  [ -0.21387851   8.12247186]
#  [  6.14141591   4.34859419]
#  [  8.5205945   -2.03080957]]

# %% [markdown]
# ##now plot them with this function:
#
# https://scipy-lectures.github.io/intro/matplotlib/matplotlib.html#scatter-plots
#
# ##if you print the array it will be a 2x100: 100 2D objects. although that is what we wanted we cannot plot it easily this way: there are many ways to deal with it. the goal is to pass the first dimension as the disrt argument to scatter, and the second dimension as the second argument. i am gonna do it by transposing the array (switching the axes)

# %%
import matplotlib.pyplot as plt
x=[]
y=[]
for i in sample1:
    x.append(i[0])
    y.append(i[1])
x2=[]
y2=[]
for i in sample2:
    x2.append(i[0])
    y2.append(i[1])
    
fig = plt.figure()
ax = fig.add_subplot(111)
plt.scatter(x,y, color = 'blue',label='sample1')
plt.scatter(x2,y2, color = 'red',label='sample2')
ax.set_ylabel('Y')
ax.set_xlabel('X')
ax.set_title("Sample1 and Sample2")
ax.legend()
plt.show()

# %% [markdown]
# ##first plot them as a single distribution, then change the color for the 2 samples
#
# remember to give your labels some names and to make a legend! in the legend tell me what the mean and standard deviation of each sample is
